# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import csv
from collections import defaultdict

columns = ['episode_reward_mean', 'episode_reward_min',
           'episode_reward_max', 'training_iteration']
res_dirs = {}
filepath = "/home/jy/ray_results/stabilizing_the_ring/" + \
	"PPO_WaveAttenuationPOEnv-v0_5cf4f8f4_2022-05-10_07-13-28o_8bn6g_/progress.csv"
rewards_data = defaultdict(list)
with open(filepath) as f:
	reader = csv.DictReader(f)
	for row in reader:
		for col in columns:
			rewards_data[col].append(float(row[col]))
#plt.figure(figsize=(16, 12))
plt.plot(rewards_data['training_iteration'],
		 rewards_data['episode_reward_mean'], label="ring_reward", c="b")
plt.fill_between(rewards_data['training_iteration'],
				 rewards_data['episode_reward_min'], rewards_data['episode_reward_max'], alpha=0.1, color="b")

plt.legend()
#plt.xlabel("iterations", fontsize=20)
#plt.xticks(fontsize=15)
#plt.yticks(fontsize=15)
plt.ylabel("mean reward")
plt.xlabel("iterations")
#plt.savefig("ring_result.pdf", bbox_inches="tight")
plt.show()

# %%
with open(filepath) as f:
	reader = csv.DictReader(f)
	for row in reader:
		for col in columns:
			rewards_data[col].append(float(row[col]))

# %%
print(rewards_data.keys())
# Out:
# dict_keys(['episode_reward_mean', 'episode_reward_min', 'episode_reward_max', 'training_iteration'])

# %%
len(rewards_data['training_iteration'])
# Out:
# 200

# %%
filepath1 = "/home/jy/ray_results/multiagent_ring/" + \
    "PPO_MultiAgentWaveAttenuationPOEnv-v1_341e8922_2022-05-20_08-12-03y0c81wl8/progress.csv"
rewards_data = defaultdict(list)
with open(filepath1) as f:
	reader = csv.DictReader(f)
	for row in reader:
		for col in columns:
			rewards_data[col].append(float(row[col]))
#plt.figure(figsize=(16, 12))
plt.plot(rewards_data['training_iteration'],
		 rewards_data['episode_reward_mean'], label="ring_reward", c="r")
plt.fill_between(rewards_data['training_iteration'],
				 rewards_data['episode_reward_min'], rewards_data['episode_reward_max'], alpha=0.1, color="r")

plt.legend()
#plt.xlabel("iterations", fontsize=20)
#plt.xticks(fontsize=15)
#plt.yticks(fontsize=15)
plt.ylabel("mean reward")
plt.xlabel("iterations")
#plt.savefig("multi_ring_result.pdf", bbox_inches="tight")
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import csv
from collections import defaultdict
from matplotlib.ticker import FuncFormatter

def formatnum(x, pos):
    return '$%.1f$' % (x/1000)
formatter = FuncFormatter(formatnum)
plt.gca().yaxis.set_major_formatter(formatter)

columns = ['episode_reward_mean', 'episode_reward_min',
           'episode_reward_max', 'training_iteration']
res_dirs = {}
filepath = "/home/jy/ray_results/stabilizing_the_ring/" + \
	"PPO_WaveAttenuationPOEnv-v0_5cf4f8f4_2022-05-10_07-13-28o_8bn6g_/progress.csv"
filepath1 = "/home/jy/ray_results/multiagent_ring/" + \
    "PPO_MultiAgentWaveAttenuationPOEnv-v1_341e8922_2022-05-20_08-12-03y0c81wl8/progress.csv"
rewards_data = defaultdict(list)
with open(filepath) as f:
	reader = csv.DictReader(f)
	for row in reader:
		for col in columns:
			rewards_data[col].append(float(row[col]))
#plt.figure(figsize=(16, 12))
plt.plot(rewards_data['training_iteration'],
		 rewards_data['episode_reward_mean'], label="single ring", c="b", linewidth=1)
plt.fill_between(rewards_data['training_iteration'],
				 rewards_data['episode_reward_min'], rewards_data['episode_reward_max'], alpha=0.1, color="b")

rewards_data = defaultdict(list)
with open(filepath1) as f:
	reader = csv.DictReader(f)
	for row in reader:
		for col in columns:
			rewards_data[col].append(float(row[col]))
#plt.figure(figsize=(16, 12))
plt.plot(rewards_data['training_iteration'],
		 rewards_data['episode_reward_mean'], label="multi ring", c="r", linewidth=1)
plt.fill_between(rewards_data['training_iteration'],
				 rewards_data['episode_reward_min'], rewards_data['episode_reward_max'], alpha=0.1, color="r")

plt.legend(loc='lower left')
#plt.xlabel("iterations", fontsize=20)
#plt.xticks(fontsize=15)
#plt.yticks(fontsize=15)
plt.ylabel("mean reward ($10^{3}$)")
plt.xlabel("iterations")
#plt.savefig("comb_ring_result.pdf", bbox_inches="tight")
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import csv
from collections import defaultdict
from matplotlib.ticker import FuncFormatter

def formatnum(x, pos):
    return '$%.1f$' % (x/1000)
formatter = FuncFormatter(formatnum)
plt.gca().yaxis.set_major_formatter(formatter)

columns = ['episode_reward_mean', 'episode_reward_min',
           'episode_reward_max', 'training_iteration']
res_dirs = {}
filepath = "/home/jy/ray_results/singleagent_figure_eight/" + \
    "PPO_AccelEnv-v0_04cb2a44_2022-05-16_05-52-180genyjvt/progress.csv"
#filepath1 = "
rewards_data = defaultdict(list)
with open(filepath) as f:
	reader = csv.DictReader(f)
	for row in reader:
		for col in columns:
			rewards_data[col].append(float(row[col]))
#plt.figure(figsize=(16, 12))
plt.plot(rewards_data['training_iteration'],
		 rewards_data['episode_reward_mean'], label="single eight", c="b", linewidth=1)
plt.fill_between(rewards_data['training_iteration'],
				 rewards_data['episode_reward_min'], rewards_data['episode_reward_max'], alpha=0.1, color="b")

# rewards_data = defaultdict(list)
# with open(filepath1) as f:
# 	reader = csv.DictReader(f)
# 	for row in reader:
# 		for col in columns:
# 			rewards_data[col].append(float(row[col]))
# #plt.figure(figsize=(16, 12))
# plt.plot(rewards_data['training_iteration'],
# 		 rewards_data['episode_reward_mean'], label="multi ring", c="r", linewidth=1)
# plt.fill_between(rewards_data['training_iteration'],
# 				 rewards_data['episode_reward_min'], rewards_data['episode_reward_max'], alpha=0.1, color="r")

plt.legend(loc='upper right')
#plt.xlabel("iterations", fontsize=20)
#plt.xticks(fontsize=15)
#plt.yticks(fontsize=15)
plt.ylabel("mean reward ($10^{3}$)")
plt.xlabel("iterations")
plt.savefig("single_figure_eight_result.pdf", bbox_inches="tight")
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import glob
import os
import csv
from collections import defaultdict

columns = ['episode_reward_mean', 'episode_reward_min',
           'episode_reward_max', 'training_iteration']
res_dirs = {}
filepath = r'D:\迅雷下载\highway-env-master\scripts\dqn_mlp_5000.xlsx'
rewards_data = defaultdict(list)
#plt.figure(figsize=(16, 12))
plt.plot(rewards_data['training_iteration'],
		 rewards_data['episode_reward_mean'], label="ring_reward", c="b")
plt.fill_between(rewards_data['training_iteration'],
				 rewards_data['episode_reward_min'], rewards_data['episode_reward_max'], alpha=0.1, color="b")

plt.legend()
#plt.xlabel("iterations", fontsize=20)
#plt.xticks(fontsize=15)
#plt.yticks(fontsize=15)
plt.ylabel("mean reward")
plt.xlabel("iterations")
#plt.savefig("ring_result.pdf", bbox_inches="tight")
plt.show()
# Out:
# -------------------------------------------------------------------------
# NameError                               Traceback (most recent call last)
# <ipython-input-3-31bde7eabdc1> in <module>
#      12 filepath = r'D:\迅雷下载\highway-env-master\scripts\dqn_mlp_5000.xlsx'
#      13 rewards_data = defaultdict(list)
# ---> 14 with open(filepath, coding=gbk) as f:
#      15         reader = csv.DictReader(f)
#      16         for row in reader:
#
# NameError: name 'gbk' is not defined
